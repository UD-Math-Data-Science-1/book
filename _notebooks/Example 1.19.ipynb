# %%
import pandas as pd

# %%
weather = pd.read_csv("../_datasets/ghcn_newark.csv")
weather.head()
# Out:
# /var/folders/gc/0752xrm56pnf0r0dsrn5370c0000gr/T/ipykernel_6460/2860724266.py:1: DtypeWarning: Columns (41,43,45,47,49,51,53,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   weather = pd.read_csv("../_datasets/ghcn_newark.csv")
#        STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00076410  1894-04-01   39.6682  -75.74569       32.3
# 1  USC00076410  1894-04-02   39.6682  -75.74569       32.3
# 2  USC00076410  1894-04-03   39.6682  -75.74569       32.3
# 3  USC00076410  1894-04-04   39.6682  -75.74569       32.3
# 4  USC00076410  1894-04-05   39.6682  -75.74569       32.3
#
#                     NAME   PRCP PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  ...  \
# 0  NEWARK AG FARM, DE US    0.0           P,,6,   NaN             NaN  ...
# 1  NEWARK AG FARM, DE US    0.0           P,,6,   NaN             NaN  ...
# 2  NEWARK AG FARM, DE US    0.0           P,,6,   NaN             NaN  ...
# 3  NEWARK AG FARM, DE US  165.0            ,,6,   NaN             NaN  ...
# 4  NEWARK AG FARM, DE US    0.0           P,,6,   NaN             NaN  ...
#
#    WT08 WT08_ATTRIBUTES  WT11 WT11_ATTRIBUTES  WT14 WT14_ATTRIBUTES  WT16  \
# 0   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 1   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 2   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 3   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 4   NaN             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT16_ATTRIBUTES  WT18 WT18_ATTRIBUTES
# 0             NaN   NaN             NaN
# 1             NaN   NaN             NaN
# 2             NaN   NaN             NaN
# 3             NaN   NaN             NaN
# 4             NaN   NaN             NaN
#
# [5 rows x 56 columns]

# %%
columns = ["DATE", "PRCP", "SNOW", "TMAX", "TMIN"]
weather = weather[columns]

# %%
weather
# Out:
#              DATE   PRCP  SNOW   TMAX   TMIN
# 0      1894-04-01    0.0   NaN  189.0  111.0
# 1      1894-04-02    0.0   NaN  133.0   22.0
# 2      1894-04-03    0.0   NaN   89.0  -61.0
# 3      1894-04-04  165.0   NaN  117.0   17.0
# 4      1894-04-05    0.0   NaN  156.0   56.0
# ...           ...    ...   ...    ...    ...
# 29512  2022-11-30   97.0   NaN  128.0    6.0
# 29513  2022-12-17    0.0   NaN   72.0   11.0
# 29514  2022-12-18    0.0   NaN   39.0  -22.0
# 29515  2023-01-06    0.0   NaN   89.0   33.0
# 29516  2023-01-07    0.0   NaN   72.0   17.0
#
# [29517 rows x 5 columns]

# %%
weather.loc[0]
# Out:
# DATE    1894-04-01
# PRCP           0.0
# SNOW           NaN
# TMAX         189.0
# TMIN         111.0
# Name: 0, dtype: object

# %%
weather.iloc[0]
# Out:
# DATE    1894-04-01
# PRCP           0.0
# SNOW           NaN
# TMAX         189.0
# TMIN         111.0
# Name: 0, dtype: object

# %%
weather.iloc[:1]
# Out:
#          DATE  PRCP  SNOW   TMAX   TMIN
# 0  1894-04-01   0.0   NaN  189.0  111.0

# %%
weather.iloc[-4:]
# Out:
#              DATE  PRCP  SNOW  TMAX  TMIN
# 29513  2022-12-17   0.0   NaN  72.0  11.0
# 29514  2022-12-18   0.0   NaN  39.0 -22.0
# 29515  2023-01-06   0.0   NaN  89.0  33.0
# 29516  2023-01-07   0.0   NaN  72.0  17.0
