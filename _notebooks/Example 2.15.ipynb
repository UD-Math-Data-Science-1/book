# %%
import seaborn as sns
import pandas as pd
weather = pd.read_csv("../_datasets/ghcn_newark.csv")
# Out:
# /var/folders/gc/0752xrm56pnf0r0dsrn5370c0000gr/T/ipykernel_90273/452418774.py:3: DtypeWarning: Columns (41,43,45,47,49,51,53,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   weather = pd.read_csv("../_datasets/ghcn_newark.csv")

# %%
sns.displot(weather, x="TMIN", bins=20, stat="density");

# %%
sns.displot(weather, x="TMIN", kind="kde");

# %%
sns.displot(weather, x="TMIN", kind="ecdf");
